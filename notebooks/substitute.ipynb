# %%
import pickle

# %%
with (open("NER/labeledParagraphs.pickle", "rb")) as openfile:
  labeledParagraphs = pickle.load(openfile)

with (open("NER/modifiableWords.pickle", "rb")) as openfile:
  modifiableWords = pickle.load(openfile)

with (open("NER/wordPosPhonemeDict.pickle", "rb")) as openfile:
  wordPosPhonemeDict = pickle.load(openfile)

# %%
print(labeledParagraphs)
# Out:
# [[['As', 'SCONJ'], ['she', 'PRON'], ['said', 'VERB'], ['these', 'DET'], ['words', 'NOUN'], ['her', 'PRON'], ['foot', 'NOUN'], ['slipped', 'VERB'], [',', 'PUNCT'], ['and', 'CCONJ'], ['in', 'ADP'], ['another', 'DET'], ['moment', 'NOUN'], [',', 'PUNCT'], ['splash', 'NOUN'], ['!', 'PUNCT'], ['she', 'PRON'], ['was', 'AUX'], ['up', 'ADP'], ['to', 'ADP'], ['her', 'PRON'], ['chin', 'NOUN'], ['in', 'ADP'], ['salt', 'NOUN'], ['water', 'NOUN'], ['.', 'PUNCT'], ['Her', 'PRON'], ['first', 'ADJ'], ['idea', 'NOUN'], ['was', 'AUX'], ['that', 'SCONJ'], ['she', 'PRON'], ['had', 'AUX'], ['somehow', 'ADV'], ['fallen', 'VERB'], ['into', 'ADP'], ['the', 'DET'], ['sea', 'NOUN'], [',', 'PUNCT'], ['“', 'PUNCT'], ['and', 'CCONJ'], ['in', 'ADP'], ['that', 'DET'], ['case', 'NOUN'], ['I', 'PRON'], ['can', 'AUX'], ['go', 'VERB'], ['back', 'ADV'], ['by', 'ADP'], ['railway', 'NOUN'], [',', 'PUNCT'], ['”', 'PUNCT'], ['she', 'PRON'], ['said', 'VERB'], ['to', 'ADP'], ['herself', 'PRON'], ['.', 'PUNCT'], ['(', 'PUNCT'], ['Alice', 'PROPN'], ['had', 'AUX'], ['been', 'AUX'], ['to', 'ADP'], ['the', 'DET'], ['seaside', 'NOUN'], ['once', 'ADV'], ['in', 'ADP'], ['her', 'PRON'], ['life', 'NOUN'], [',', 'PUNCT'], ['and', 'CCONJ'], ['had', 'AUX'], ['come', 'VERB'], ['to', 'ADP'], ['the', 'DET'], ['general', 'ADJ'], ['conclusion', 'NOUN'], [',', 'PUNCT'], ['that', 'SCONJ'], ['wherever', 'SCONJ'], ['you', 'PRON'], ['go', 'VERB'], ['to', 'ADP'], ['on', 'ADP'], ['the', 'DET'], ['English', 'ADJ'], ['coast', 'NOUN'], ['you', 'PRON'], ['find', 'VERB'], ['a', 'DET'], ['number', 'NOUN'], ['of', 'ADP'], ['bathing', 'NOUN'], ['machines', 'NOUN'], ['in', 'ADP'], ['the', 'DET'], ['sea', 'NOUN'], [',', 'PUNCT'], ['some', 'DET'], ['children', 'NOUN'], ['digging', 'VERB'], ['in', 'ADP'], ['the', 'DET'], ['sand', 'NOUN'], ['with', 'ADP'], ['wooden', 'ADJ'], ['spades', 'NOUN'], [',', 'PUNCT'], ['then', 'ADV'], ['a', 'DET'], ['row', 'NOUN'], ['of', 'ADP'], ['lodging', 'VERB'], ['houses', 'NOUN'], [',', 'PUNCT'], ['and', 'CCONJ'], ['behind', 'ADP'], ['them', 'PRON'], ['a', 'DET'], ['railway', 'NOUN'], ['station', 'NOUN'], ['.', 'PUNCT'], [')', 'PUNCT'], ['However', 'ADV'], [',', 'PUNCT'], ['she', 'PRON'], ['soon', 'ADV'], ['made', 'VERB'], ['out', 'ADP'], ['that', 'SCONJ'], ['she', 'PRON'], ['was', 'AUX'], ['in', 'ADP'], ['the', 'DET'], ['pool', 'NOUN'], ['of', 'ADP'], ['tears', 'NOUN'], ['which', 'PRON'], ['she', 'PRON'], ['had', 'AUX'], ['wept', 'VERB'], ['when', 'SCONJ'], ['she', 'PRON'], ['was', 'AUX'], ['nine', 'NUM'], ['feet', 'NOUN'], ['high', 'ADJ']], [['The', 'DET'], ['first', 'ADJ'], ['question', 'NOUN'], ['of', 'ADP'], ['course', 'NOUN'], ['was', 'AUX'], [',', 'PUNCT'], ['how', 'SCONJ'], ['to', 'PART'], ['get', 'VERB'], ['dry', 'ADJ'], ['again', 'ADV'], [':', 'PUNCT'], ['they', 'PRON'], ['had', 'VERB'], ['a', 'DET'], ['consultation', 'NOUN'], ['about', 'ADP'], ['this', 'PRON'], [',', 'PUNCT'], ['and', 'CCONJ'], ['after', 'ADP'], ['a', 'DET'], ['few', 'ADJ'], ['minutes', 'NOUN'], ['it', 'PRON'], ['seemed', 'VERB'], ['quite', 'ADV'], ['natural', 'ADJ'], ['to', 'ADP'], ['Alice', 'PROPN'], ['to', 'PART'], ['find', 'VERB'], ['herself', 'PRON'], ['talking', 'VERB'], ['familiarly', 'ADV'], ['with', 'ADP'], ['them', 'PRON'], [',', 'PUNCT'], ['as', 'SCONJ'], ['if', 'SCONJ'], ['she', 'PRON'], ['had', 'AUX'], ['known', 'VERB'], ['them', 'PRON'], ['all', 'DET'], ['her', 'PRON'], ['life', 'NOUN'], ['.', 'PUNCT'], ['Indeed', 'ADV'], [',', 'PUNCT'], ['she', 'PRON'], ['had', 'VERB'], ['quite', 'DET'], ['a', 'DET'], ['long', 'ADJ'], ['argument', 'NOUN'], ['with', 'ADP'], ['the', 'DET'], ['Lory', 'PROPN'], [',', 'PUNCT'], ['who', 'PRON'], ['at', 'ADP'], ['last', 'ADV'], ['turned', 'VERB'], ['sulky', 'ADJ'], [',', 'PUNCT'], ['and', 'CCONJ'], ['would', 'AUX'], ['only', 'ADV'], ['say', 'VERB'], [',', 'PUNCT'], ['“', 'PUNCT'], ['I', 'PRON'], ['am', 'AUX'], ['older', 'ADJ'], ['than', 'ADP'], ['you', 'PRON'], [',', 'PUNCT'], ['and', 'CCONJ'], ['must', 'AUX'], ['know', 'VERB'], ['better', 'ADV'], [';', 'P ...

# %%
for paragraph in labeledParagraphs:
  paragraph_text = ""
  for word in paragraph:
    print(word)
    # if word[1] in modifiableWords:
      # paragraph_text += 
    # else:
# Out:
# ['As', 'SCONJ']
# ['she', 'PRON']
# ['said', 'VERB']
# ['these', 'DET']
# ['words', 'NOUN']
# ['her', 'PRON']
# ['foot', 'NOUN']
# ['slipped', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['in', 'ADP']
# ['another', 'DET']
# ['moment', 'NOUN']
# [',', 'PUNCT']
# ['splash', 'NOUN']
# ['!', 'PUNCT']
# ['she', 'PRON']
# ['was', 'AUX']
# ['up', 'ADP']
# ['to', 'ADP']
# ['her', 'PRON']
# ['chin', 'NOUN']
# ['in', 'ADP']
# ['salt', 'NOUN']
# ['water', 'NOUN']
# ['.', 'PUNCT']
# ['Her', 'PRON']
# ['first', 'ADJ']
# ['idea', 'NOUN']
# ['was', 'AUX']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['had', 'AUX']
# ['somehow', 'ADV']
# ['fallen', 'VERB']
# ['into', 'ADP']
# ['the', 'DET']
# ['sea', 'NOUN']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['and', 'CCONJ']
# ['in', 'ADP']
# ['that', 'DET']
# ['case', 'NOUN']
# ['I', 'PRON']
# ['can', 'AUX']
# ['go', 'VERB']
# ['back', 'ADV']
# ['by', 'ADP']
# ['railway', 'NOUN']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['she', 'PRON']
# ['said', 'VERB']
# ['to', 'ADP']
# ['herself', 'PRON']
# ['.', 'PUNCT']
# ['(', 'PUNCT']
# ['Alice', 'PROPN']
# ['had', 'AUX']
# ['been', 'AUX']
# ['to', 'ADP']
# ['the', 'DET']
# ['seaside', 'NOUN']
# ['once', 'ADV']
# ['in', 'ADP']
# ['her', 'PRON']
# ['life', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['had', 'AUX']
# ['come', 'VERB']
# ['to', 'ADP']
# ['the', 'DET']
# ['general', 'ADJ']
# ['conclusion', 'NOUN']
# [',', 'PUNCT']
# ['that', 'SCONJ']
# ['wherever', 'SCONJ']
# ['you', 'PRON']
# ['go', 'VERB']
# ['to', 'ADP']
# ['on', 'ADP']
# ['the', 'DET']
# ['English', 'ADJ']
# ['coast', 'NOUN']
# ['you', 'PRON']
# ['find', 'VERB']
# ['a', 'DET']
# ['number', 'NOUN']
# ['of', 'ADP']
# ['bathing', 'NOUN']
# ['machines', 'NOUN']
# ['in', 'ADP']
# ['the', 'DET']
# ['sea', 'NOUN']
# [',', 'PUNCT']
# ['some', 'DET']
# ['children', 'NOUN']
# ['digging', 'VERB']
# ['in', 'ADP']
# ['the', 'DET']
# ['sand', 'NOUN']
# ['with', 'ADP']
# ['wooden', 'ADJ']
# ['spades', 'NOUN']
# [',', 'PUNCT']
# ['then', 'ADV']
# ['a', 'DET']
# ['row', 'NOUN']
# ['of', 'ADP']
# ['lodging', 'VERB']
# ['houses', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['behind', 'ADP']
# ['them', 'PRON']
# ['a', 'DET']
# ['railway', 'NOUN']
# ['station', 'NOUN']
# ['.', 'PUNCT']
# [')', 'PUNCT']
# ['However', 'ADV']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['soon', 'ADV']
# ['made', 'VERB']
# ['out', 'ADP']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['in', 'ADP']
# ['the', 'DET']
# ['pool', 'NOUN']
# ['of', 'ADP']
# ['tears', 'NOUN']
# ['which', 'PRON']
# ['she', 'PRON']
# ['had', 'AUX']
# ['wept', 'VERB']
# ['when', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['nine', 'NUM']
# ['feet', 'NOUN']
# ['high', 'ADJ']
# ['The', 'DET']
# ['first', 'ADJ']
# ['question', 'NOUN']
# ['of', 'ADP']
# ['course', 'NOUN']
# ['was', 'AUX']
# [',', 'PUNCT']
# ['how', 'SCONJ']
# ['to', 'PART']
# ['get', 'VERB']
# ['dry', 'ADJ']
# ['again', 'ADV']
# [':', 'PUNCT']
# ['they', 'PRON']
# ['had', 'VERB']
# ['a', 'DET']
# ['consultation', 'NOUN']
# ['about', 'ADP']
# ['this', 'PRON']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['after', 'ADP']
# ['a', 'DET']
# ['few', 'ADJ']
# ['minutes', 'NOUN']
# ['it', 'PRON']
# ['seemed', 'VERB']
# ['quite', 'ADV']
# ['natural', 'ADJ']
# ['to', 'ADP']
# ['Alice', 'PROPN']
# ['to', 'PART']
# ['find', 'VERB']
# ['herself', 'PRON']
# ['talking', 'VERB']
# ['familiarly', 'ADV']
# ['with', 'ADP']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['if', 'SCONJ']
# ['she', 'PRON']
# ['had', 'AUX']
# ['known', 'VERB']
# ['them', 'PRON']
# ['all', 'DET']
# ['her', 'PRON']
# ['life', 'NOUN']
# ['.', 'PUNCT']
# ['Indeed', 'ADV']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['had', 'VERB']
# ['quite', 'DET']
# ['a', 'DET']
# ['long', 'ADJ']
# ['argument', 'NOUN']
# ['with', 'ADP']
# ['the', 'DET']
# ['Lory', 'PROPN']
# [',', 'PUNCT']
# ['who', 'PRON']
# ['at', 'ADP']
# ['last', 'ADV']
# ['turned', 'VERB']
# ['sulky', 'ADJ']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['would', 'AUX']
# ['only', 'ADV']
# ['say', 'VERB']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['I', 'PRON']
# ['am', 'AUX']
# ['older', 'ADJ']
# ['than', 'ADP']
# ['you', 'PRON']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['must', 'AUX']
# ['know', 'VERB']
# ['better', 'ADV']
# [';', 'PUNCT']
# ['”', 'PUNCT']
# ['and', 'CCONJ']
# ['this', 'PRON']
# ['Alice', 'PROPN']
# ['would', 'AUX']
# ['not', 'PART']
# ['allow', 'VERB']
# [',', 'PUNCT']
# ['without', 'ADP']
# ['knowing', 'VERB']
# ['how', 'SCONJ']
# ['old', 'ADJ']
# ['it', 'PRON']
# ['was', 'AUX']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['the', 'DET']
# ['Lory', 'PROPN']
# ['positively', 'ADV']
# ['refused', 'VERB']
# ['to', 'PART']
# ['tell', 'VERB']
# ['its', 'PRON']
# ['age', 'NOUN']
# [',', 'PUNCT']
# ['there', 'PRON']
# ['was', 'VERB']
# ['no', 'ADV']
# ['more', 'ADJ']
# ['to', 'PART']
# ['be', 'AUX']
# ['said', 'VERB']
# ['.', 'PUNCT']
# ['First', 'ADV']
# ['it', 'PRON']
# ['marked', 'VERB']
# ['out', 'ADP']
# ['a', 'DET']
# ['race', 'NOUN']
# ['-', 'PUNCT']
# ['course', 'NOUN']
# [',', 'PUNCT']
# ['in', 'ADP']
# ['a', 'DET']
# ['sort', 'NOUN']
# ['of', 'ADP']
# ['circle', 'NOUN']
# [',', 'PUNCT']
# ['(', 'PUNCT']
# ['“', 'PUNCT']
# ['the', 'DET']
# ['exact', 'ADJ']
# ['shape', 'NOUN']
# ['doesn', 'VERB']
# ['’', 'PUNCT']
# ['t', 'NOUN']
# ['matter', 'NOUN']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['it', 'PRON']
# ['said', 'VERB']
# [',', 'PUNCT']
# [')', 'PUNCT']
# ['and', 'CCONJ']
# ['then', 'ADV']
# ['all', 'DET']
# ['the', 'DET']
# ['party', 'NOUN']
# ['were', 'AUX']
# ['placed', 'VERB']
# ['along', 'ADP']
# ['the', 'DET']
# ['course', 'NOUN']
# [',', 'PUNCT']
# ['here', 'ADV']
# ['and', 'CCONJ']
# ['there', 'ADV']
# ['.', 'PUNCT']
# ['There', 'PRON']
# ['was', 'VERB']
# ['no', 'DET']
# ['“', 'PUNCT']
# ['One', 'NUM']
# [',', 'PUNCT']
# ['two', 'NUM']
# [',', 'PUNCT']
# ['three', 'NUM']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['away', 'ADV']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['but', 'CCONJ']
# ['they', 'PRON']
# ['began', 'VERB']
# ['running', 'VERB']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['liked', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['left', 'VERB']
# ['off', 'ADP']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['liked', 'VERB']
# [',', 'PUNCT']
# ['so', 'SCONJ']
# ['that', 'SCONJ']
# ['it', 'PRON']
# ['was', 'AUX']
# ['not', 'PART']
# ['easy', 'ADJ']
# ['to', 'PART']
# ['know', 'VERB']
# ['when', 'SCONJ']
# ['the', 'DET']
# ['race', 'NOUN']
# ['was', 'AUX']
# ['over', 'ADV']
# ['.', 'PUNCT']
# ['However', 'ADV']
# [',', 'PUNCT']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['had', 'AUX']
# ['been', 'AUX']
# ['running', 'VERB']
# ['halfan', 'NOUN']
# ['-', 'PUNCT']
# ['hour', 'NOUN']
# ['or', 'CCONJ']
# ['so', 'ADV']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['were', 'AUX']
# ['quite', 'ADV']
# ['dry', 'ADJ']
# ['again', 'ADV']
# [',', 'PUNCT']
# ['the', 'DET']
# ['Dodo', 'PROPN']
# ['suddenly', 'ADV']
# ['called', 'VERB']
# ['out', 'ADP']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['The', 'DET']
# ['race', 'NOUN']
# ['is', 'AUX']
# ['over', 'ADV']
# ['!', 'PUNCT']
# ['”', 'PUNCT']
# ['and', 'CCONJ']
# ['they', 'PRON']
# ['all', 'PRON']
# ['crowded', 'VERB']
# ['round', 'ADV']
# ['it', 'PRON']
# [',', 'PUNCT']
# ['panting', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['asking', 'VERB']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['But', 'CCONJ']
# ['who', 'PRON']
# ['has', 'AUX']
# ['won', 'VERB']
# ['?', 'PUNCT']
# ['”', 'PUNCT']
# ['IT', 'PRON']
# ['was', 'AUX']
# ['the', 'DET']
# ['White', 'PROPN']
# ['Rabbit', 'PROPN']
# [',', 'PUNCT']
# ['trotting', 'VERB']
# ['slowly', 'ADV']
# ['back', 'ADV']
# ['again', 'ADV']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['looking', 'VERB']
# ['anxiously', 'ADV']
# ['about', 'ADP']
# ['as', 'SCONJ']
# ['it', 'PRON']
# ['went', 'VERB']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['if', 'SCONJ']
# ['it', 'PRON']
# ['had', 'AUX']
# ['lost', 'VERB']
# ['something', 'PRON']
# [';', 'PUNCT']
# ['and', 'CCONJ']
# ['she', 'PRON']
# ['heard', 'VERB']
# ['it', 'PRON']
# ['muttering', 'VERB']
# ['to', 'ADP']
# ['itself', 'PRON']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['The', 'DET']
# ['Duchess', 'PROPN']
# ['!', 'PUNCT']
# ['The', 'DET']
# ['Duchess', 'PROPN']
# ['!', 'PUNCT']
# ['Oh', 'INTJ']
# ['my', 'PRON']
# ['dear', 'ADJ']
# ['paws', 'NOUN']
# ['!', 'PUNCT']
# ['Oh', 'INTJ']
# ['my', 'PRON']
# ['fur', 'NOUN']
# ['and', 'CCONJ']
# ['whiskers', 'NOUN']
# ['!', 'PUNCT']
# ['She', 'PRON']
# ['’ll', 'AUX']
# ['get', 'VERB']
# ['me', 'PRON']
# ['executed', 'VERB']
# [',', 'PUNCT']
# ['as', 'ADV']
# ['sure', 'ADJ']
# ['as', 'SCONJ']
# ['ferrets', 'NOUN']
# ['are', 'AUX']
# ['ferrets', 'NOUN']
# ['!', 'PUNCT']
# ['Where', 'SCONJ']
# ['can', 'AUX']
# ['I', 'PRON']
# ['have', 'AUX']
# ['dropped', 'VERB']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['I', 'PRON']
# ['wonder', 'VERB']
# ['!', 'PUNCT']
# ['”', 'PUNCT']
# ['Alice', 'PROPN']
# ['guessed', 'VERB']
# ['in', 'ADP']
# ['a', 'DET']
# ['moment', 'NOUN']
# ['that', 'SCONJ']
# ['it', 'PRON']
# ['was', 'AUX']
# ['looking', 'VERB']
# ['for', 'ADP']
# ['the', 'DET']
# ['fan', 'NOUN']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['pair', 'NOUN']
# ['of', 'ADP']
# ['white', 'ADJ']
# ['kid', 'NOUN']
# ['gloves', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['she', 'PRON']
# ['very', 'ADV']
# ['goodnaturedly', 'ADV']
# ['began', 'VERB']
# ['hunting', 'VERB']
# ['about', 'ADP']
# ['for', 'ADP']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['but', 'CCONJ']
# ['they', 'PRON']
# ['were', 'AUX']
# ['nowhere', 'ADV']
# ['to', 'PART']
# ['be', 'AUX']
# ['seen', 'VERB']
# ['—', 'PUNCT']
# ['everything', 'PRON']
# ['seemed', 'VERB']
# ['to', 'PART']
# ['have', 'AUX']
# ['changed', 'VERB']
# ['since', 'SCONJ']
# ['her', 'PRON']
# ['swim', 'NOUN']
# ['in', 'ADP']
# ['the', 'DET']
# ['pool', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['great', 'ADJ']
# ['hall', 'NOUN']
# [',', 'PUNCT']
# ['with', 'ADP']
# ['the', 'DET']
# ['glass', 'NOUN']
# ['table', 'NOUN']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['little', 'ADJ']
# ['door', 'NOUN']
# [',', 'PUNCT']
# ['had', 'AUX']
# ['vanished', 'VERB']
# ['completely', 'ADV']
# ['.', 'PUNCT']
# ['So', 'ADV']
# ['she', 'PRON']
# ['swallowed', 'VERB']
# ['one', 'NUM']
# ['of', 'ADP']
# ['the', 'DET']
# ['cakes', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['was', 'AUX']
# ['delighted', 'ADJ']
# ['to', 'PART']
# ['find', 'VERB']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['began', 'VERB']
# ['shrinking', 'VERB']
# ['directly', 'ADV']
# ['.', 'PUNCT']
# ['As', 'ADV']
# ['soon', 'ADV']
# ['as', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['small', 'ADJ']
# ['enough', 'ADV']
# ['to', 'PART']
# ['get', 'VERB']
# ['through', 'ADP']
# ['the', 'DET']
# ['door', 'NOUN']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['ran', 'VERB']
# ['out', 'ADP']
# ['of', 'ADP']
# ['the', 'DET']
# ['house', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['found', 'VERB']
# ['quite', 'DET']
# ['a', 'DET']
# ['crowd', 'NOUN']
# ['of', 'ADP']
# ['little', 'ADJ']
# ['animals', 'NOUN']
# ['and', 'CCONJ']
# ['birds', 'NOUN']
# ['waiting', 'VERB']
# ['outside', 'ADV']
# ['.', 'PUNCT']
# ['The', 'DET']
# ['poor', 'ADJ']
# ['little', 'ADJ']
# ['Lizard', 'NOUN']
# [',', 'PUNCT']
# ['Bill', 'PROPN']
# [',', 'PUNCT']
# ['was', 'AUX']
# ['in', 'ADP']
# ['the', 'DET']
# ['middle', 'NOUN']
# [',', 'PUNCT']
# ['being', 'AUX']
# ['held', 'VERB']
# ['up', 'ADP']
# ['by', 'ADP']
# ['two', 'NUM']
# ['guinea', 'NOUN']
# ['-', 'PUNCT']
# ['pigs', 'NOUN']
# [',', 'PUNCT']
# ['who', 'PRON']
# ['were', 'AUX']
# ['giving', 'VERB']
# ['it', 'PRON']
# ['something', 'PRON']
# ['out', 'ADP']
# ['of', 'ADP']
# ['a', 'DET']
# ['bottle', 'NOUN']
# ['.', 'PUNCT']
# ['They', 'PRON']
# ['all', 'PRON']
# ['made', 'VERB']
# ['a', 'DET']
# ['rush', 'NOUN']
# ['at', 'ADP']
# ['Alice', 'PROPN']
# ['the', 'DET']
# ['moment', 'NOUN']
# ['she', 'PRON']
# ['appeared', 'VERB']
# [',', 'PUNCT']
# ['but', 'CCONJ']
# ['she', 'PRON']
# ['ran', 'VERB']
# ['off', 'ADP']
# ['as', 'ADV']
# ['hard', 'ADV']
# ['as', 'SCONJ']
# ['she', 'PRON']
# ['could', 'AUX']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['soon', 'ADV']
# ['found', 'VERB']
# ['herself', 'PRON']
# ['safe', 'ADJ']
# ['in', 'ADP']
# ['a', 'DET']
# ['thick', 'ADJ']
# ['wood', 'NOUN']
# ['.', 'PUNCT']
# ['As', 'SCONJ']
# ['she', 'PRON']
# ['said', 'VERB']
# ['these', 'DET']
# ['words', 'NOUN']
# ['her', 'PRON']
# ['foot', 'NOUN']
# ['slipped', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['in', 'ADP']
# ['another', 'DET']
# ['moment', 'NOUN']
# [',', 'PUNCT']
# ['splash', 'NOUN']
# ['!', 'PUNCT']
# ['she', 'PRON']
# ['was', 'AUX']
# ['up', 'ADP']
# ['to', 'ADP']
# ['her', 'PRON']
# ['chin', 'NOUN']
# ['in', 'ADP']
# ['salt', 'NOUN']
# ['water', 'NOUN']
# ['.', 'PUNCT']
# ['Her', 'PRON']
# ['first', 'ADJ']
# ['idea', 'NOUN']
# ['was', 'AUX']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['had', 'AUX']
# ['somehow', 'ADV']
# ['fallen', 'VERB']
# ['into', 'ADP']
# ['the', 'DET']
# ['sea', 'NOUN']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['and', 'CCONJ']
# ['in', 'ADP']
# ['that', 'DET']
# ['case', 'NOUN']
# ['I', 'PRON']
# ['can', 'AUX']
# ['go', 'VERB']
# ['back', 'ADV']
# ['by', 'ADP']
# ['railway', 'NOUN']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['she', 'PRON']
# ['said', 'VERB']
# ['to', 'ADP']
# ['herself', 'PRON']
# ['.', 'PUNCT']
# ['(', 'PUNCT']
# ['Alice', 'PROPN']
# ['had', 'AUX']
# ['been', 'AUX']
# ['to', 'ADP']
# ['the', 'DET']
# ['seaside', 'NOUN']
# ['once', 'ADV']
# ['in', 'ADP']
# ['her', 'PRON']
# ['life', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['had', 'AUX']
# ['come', 'VERB']
# ['to', 'ADP']
# ['the', 'DET']
# ['general', 'ADJ']
# ['conclusion', 'NOUN']
# [',', 'PUNCT']
# ['that', 'SCONJ']
# ['wherever', 'SCONJ']
# ['you', 'PRON']
# ['go', 'VERB']
# ['to', 'ADP']
# ['on', 'ADP']
# ['the', 'DET']
# ['English', 'ADJ']
# ['coast', 'NOUN']
# ['you', 'PRON']
# ['find', 'VERB']
# ['a', 'DET']
# ['number', 'NOUN']
# ['of', 'ADP']
# ['bathing', 'NOUN']
# ['machines', 'NOUN']
# ['in', 'ADP']
# ['the', 'DET']
# ['sea', 'NOUN']
# [',', 'PUNCT']
# ['some', 'DET']
# ['children', 'NOUN']
# ['digging', 'VERB']
# ['in', 'ADP']
# ['the', 'DET']
# ['sand', 'NOUN']
# ['with', 'ADP']
# ['wooden', 'ADJ']
# ['spades', 'NOUN']
# [',', 'PUNCT']
# ['then', 'ADV']
# ['a', 'DET']
# ['row', 'NOUN']
# ['of', 'ADP']
# ['lodging', 'VERB']
# ['houses', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['behind', 'ADP']
# ['them', 'PRON']
# ['a', 'DET']
# ['railway', 'NOUN']
# ['station', 'NOUN']
# ['.', 'PUNCT']
# [')', 'PUNCT']
# ['However', 'ADV']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['soon', 'ADV']
# ['made', 'VERB']
# ['out', 'ADP']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['in', 'ADP']
# ['the', 'DET']
# ['pool', 'NOUN']
# ['of', 'ADP']
# ['tears', 'NOUN']
# ['which', 'PRON']
# ['she', 'PRON']
# ['had', 'AUX']
# ['wept', 'VERB']
# ['when', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['nine', 'NUM']
# ['feet', 'NOUN']
# ['high', 'ADJ']
# ['The', 'DET']
# ['first', 'ADJ']
# ['question', 'NOUN']
# ['of', 'ADP']
# ['course', 'NOUN']
# ['was', 'AUX']
# [',', 'PUNCT']
# ['how', 'SCONJ']
# ['to', 'PART']
# ['get', 'VERB']
# ['dry', 'ADJ']
# ['again', 'ADV']
# [':', 'PUNCT']
# ['they', 'PRON']
# ['had', 'VERB']
# ['a', 'DET']
# ['consultation', 'NOUN']
# ['about', 'ADP']
# ['this', 'PRON']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['after', 'ADP']
# ['a', 'DET']
# ['few', 'ADJ']
# ['minutes', 'NOUN']
# ['it', 'PRON']
# ['seemed', 'VERB']
# ['quite', 'ADV']
# ['natural', 'ADJ']
# ['to', 'ADP']
# ['Alice', 'PROPN']
# ['to', 'PART']
# ['find', 'VERB']
# ['herself', 'PRON']
# ['talking', 'VERB']
# ['familiarly', 'ADV']
# ['with', 'ADP']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['if', 'SCONJ']
# ['she', 'PRON']
# ['had', 'AUX']
# ['known', 'VERB']
# ['them', 'PRON']
# ['all', 'DET']
# ['her', 'PRON']
# ['life', 'NOUN']
# ['.', 'PUNCT']
# ['Indeed', 'ADV']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['had', 'VERB']
# ['quite', 'DET']
# ['a', 'DET']
# ['long', 'ADJ']
# ['argument', 'NOUN']
# ['with', 'ADP']
# ['the', 'DET']
# ['Lory', 'PROPN']
# [',', 'PUNCT']
# ['who', 'PRON']
# ['at', 'ADP']
# ['last', 'ADV']
# ['turned', 'VERB']
# ['sulky', 'ADJ']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['would', 'AUX']
# ['only', 'ADV']
# ['say', 'VERB']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['I', 'PRON']
# ['am', 'AUX']
# ['older', 'ADJ']
# ['than', 'ADP']
# ['you', 'PRON']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['must', 'AUX']
# ['know', 'VERB']
# ['better', 'ADV']
# [';', 'PUNCT']
# ['”', 'PUNCT']
# ['and', 'CCONJ']
# ['this', 'PRON']
# ['Alice', 'PROPN']
# ['would', 'AUX']
# ['not', 'PART']
# ['allow', 'VERB']
# [',', 'PUNCT']
# ['without', 'ADP']
# ['knowing', 'VERB']
# ['how', 'SCONJ']
# ['old', 'ADJ']
# ['it', 'PRON']
# ['was', 'AUX']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['the', 'DET']
# ['Lory', 'PROPN']
# ['positively', 'ADV']
# ['refused', 'VERB']
# ['to', 'PART']
# ['tell', 'VERB']
# ['its', 'PRON']
# ['age', 'NOUN']
# [',', 'PUNCT']
# ['there', 'PRON']
# ['was', 'VERB']
# ['no', 'ADV']
# ['more', 'ADJ']
# ['to', 'PART']
# ['be', 'AUX']
# ['said', 'VERB']
# ['.', 'PUNCT']
# ['First', 'ADV']
# ['it', 'PRON']
# ['marked', 'VERB']
# ['out', 'ADP']
# ['a', 'DET']
# ['race', 'NOUN']
# ['-', 'PUNCT']
# ['course', 'NOUN']
# [',', 'PUNCT']
# ['in', 'ADP']
# ['a', 'DET']
# ['sort', 'NOUN']
# ['of', 'ADP']
# ['circle', 'NOUN']
# [',', 'PUNCT']
# ['(', 'PUNCT']
# ['“', 'PUNCT']
# ['the', 'DET']
# ['exact', 'ADJ']
# ['shape', 'NOUN']
# ['doesn', 'VERB']
# ['’', 'PUNCT']
# ['t', 'NOUN']
# ['matter', 'NOUN']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['it', 'PRON']
# ['said', 'VERB']
# [',', 'PUNCT']
# [')', 'PUNCT']
# ['and', 'CCONJ']
# ['then', 'ADV']
# ['all', 'DET']
# ['the', 'DET']
# ['party', 'NOUN']
# ['were', 'AUX']
# ['placed', 'VERB']
# ['along', 'ADP']
# ['the', 'DET']
# ['course', 'NOUN']
# [',', 'PUNCT']
# ['here', 'ADV']
# ['and', 'CCONJ']
# ['there', 'ADV']
# ['.', 'PUNCT']
# ['There', 'PRON']
# ['was', 'VERB']
# ['no', 'DET']
# ['“', 'PUNCT']
# ['One', 'NUM']
# [',', 'PUNCT']
# ['two', 'NUM']
# [',', 'PUNCT']
# ['three', 'NUM']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['away', 'ADV']
# [',', 'PUNCT']
# ['”', 'PUNCT']
# ['but', 'CCONJ']
# ['they', 'PRON']
# ['began', 'VERB']
# ['running', 'VERB']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['liked', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['left', 'VERB']
# ['off', 'ADP']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['liked', 'VERB']
# [',', 'PUNCT']
# ['so', 'SCONJ']
# ['that', 'SCONJ']
# ['it', 'PRON']
# ['was', 'AUX']
# ['not', 'PART']
# ['easy', 'ADJ']
# ['to', 'PART']
# ['know', 'VERB']
# ['when', 'SCONJ']
# ['the', 'DET']
# ['race', 'NOUN']
# ['was', 'AUX']
# ['over', 'ADV']
# ['.', 'PUNCT']
# ['However', 'ADV']
# [',', 'PUNCT']
# ['when', 'SCONJ']
# ['they', 'PRON']
# ['had', 'AUX']
# ['been', 'AUX']
# ['running', 'VERB']
# ['halfan', 'NOUN']
# ['-', 'PUNCT']
# ['hour', 'NOUN']
# ['or', 'CCONJ']
# ['so', 'ADV']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['were', 'AUX']
# ['quite', 'ADV']
# ['dry', 'ADJ']
# ['again', 'ADV']
# [',', 'PUNCT']
# ['the', 'DET']
# ['Dodo', 'PROPN']
# ['suddenly', 'ADV']
# ['called', 'VERB']
# ['out', 'ADP']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['The', 'DET']
# ['race', 'NOUN']
# ['is', 'AUX']
# ['over', 'ADV']
# ['!', 'PUNCT']
# ['”', 'PUNCT']
# ['and', 'CCONJ']
# ['they', 'PRON']
# ['all', 'PRON']
# ['crowded', 'VERB']
# ['round', 'ADV']
# ['it', 'PRON']
# [',', 'PUNCT']
# ['panting', 'VERB']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['asking', 'VERB']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['But', 'CCONJ']
# ['who', 'PRON']
# ['has', 'AUX']
# ['won', 'VERB']
# ['?', 'PUNCT']
# ['”', 'PUNCT']
# ['IT', 'PRON']
# ['was', 'AUX']
# ['the', 'DET']
# ['White', 'PROPN']
# ['Rabbit', 'PROPN']
# [',', 'PUNCT']
# ['trotting', 'VERB']
# ['slowly', 'ADV']
# ['back', 'ADV']
# ['again', 'ADV']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['looking', 'VERB']
# ['anxiously', 'ADV']
# ['about', 'ADP']
# ['as', 'SCONJ']
# ['it', 'PRON']
# ['went', 'VERB']
# [',', 'PUNCT']
# ['as', 'SCONJ']
# ['if', 'SCONJ']
# ['it', 'PRON']
# ['had', 'AUX']
# ['lost', 'VERB']
# ['something', 'PRON']
# [';', 'PUNCT']
# ['and', 'CCONJ']
# ['she', 'PRON']
# ['heard', 'VERB']
# ['it', 'PRON']
# ['muttering', 'VERB']
# ['to', 'ADP']
# ['itself', 'PRON']
# [',', 'PUNCT']
# ['“', 'PUNCT']
# ['The', 'DET']
# ['Duchess', 'PROPN']
# ['!', 'PUNCT']
# ['The', 'DET']
# ['Duchess', 'PROPN']
# ['!', 'PUNCT']
# ['Oh', 'INTJ']
# ['my', 'PRON']
# ['dear', 'ADJ']
# ['paws', 'NOUN']
# ['!', 'PUNCT']
# ['Oh', 'INTJ']
# ['my', 'PRON']
# ['fur', 'NOUN']
# ['and', 'CCONJ']
# ['whiskers', 'NOUN']
# ['!', 'PUNCT']
# ['She', 'PRON']
# ['’ll', 'AUX']
# ['get', 'VERB']
# ['me', 'PRON']
# ['executed', 'VERB']
# [',', 'PUNCT']
# ['as', 'ADV']
# ['sure', 'ADJ']
# ['as', 'SCONJ']
# ['ferrets', 'NOUN']
# ['are', 'AUX']
# ['ferrets', 'NOUN']
# ['!', 'PUNCT']
# ['Where', 'SCONJ']
# ['can', 'AUX']
# ['I', 'PRON']
# ['have', 'AUX']
# ['dropped', 'VERB']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['I', 'PRON']
# ['wonder', 'VERB']
# ['!', 'PUNCT']
# ['”', 'PUNCT']
# ['Alice', 'PROPN']
# ['guessed', 'VERB']
# ['in', 'ADP']
# ['a', 'DET']
# ['moment', 'NOUN']
# ['that', 'SCONJ']
# ['it', 'PRON']
# ['was', 'AUX']
# ['looking', 'VERB']
# ['for', 'ADP']
# ['the', 'DET']
# ['fan', 'NOUN']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['pair', 'NOUN']
# ['of', 'ADP']
# ['white', 'ADJ']
# ['kid', 'NOUN']
# ['gloves', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['she', 'PRON']
# ['very', 'ADV']
# ['goodnaturedly', 'ADV']
# ['began', 'VERB']
# ['hunting', 'VERB']
# ['about', 'ADP']
# ['for', 'ADP']
# ['them', 'PRON']
# [',', 'PUNCT']
# ['but', 'CCONJ']
# ['they', 'PRON']
# ['were', 'AUX']
# ['nowhere', 'ADV']
# ['to', 'PART']
# ['be', 'AUX']
# ['seen', 'VERB']
# ['—', 'PUNCT']
# ['everything', 'PRON']
# ['seemed', 'VERB']
# ['to', 'PART']
# ['have', 'AUX']
# ['changed', 'VERB']
# ['since', 'SCONJ']
# ['her', 'PRON']
# ['swim', 'NOUN']
# ['in', 'ADP']
# ['the', 'DET']
# ['pool', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['great', 'ADJ']
# ['hall', 'NOUN']
# [',', 'PUNCT']
# ['with', 'ADP']
# ['the', 'DET']
# ['glass', 'NOUN']
# ['table', 'NOUN']
# ['and', 'CCONJ']
# ['the', 'DET']
# ['little', 'ADJ']
# ['door', 'NOUN']
# [',', 'PUNCT']
# ['had', 'AUX']
# ['vanished', 'VERB']
# ['completely', 'ADV']
# ['.', 'PUNCT']
# ['So', 'ADV']
# ['she', 'PRON']
# ['swallowed', 'VERB']
# ['one', 'NUM']
# ['of', 'ADP']
# ['the', 'DET']
# ['cakes', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['was', 'AUX']
# ['delighted', 'ADJ']
# ['to', 'PART']
# ['find', 'VERB']
# ['that', 'SCONJ']
# ['she', 'PRON']
# ['began', 'VERB']
# ['shrinking', 'VERB']
# ['directly', 'ADV']
# ['.', 'PUNCT']
# ['As', 'ADV']
# ['soon', 'ADV']
# ['as', 'SCONJ']
# ['she', 'PRON']
# ['was', 'AUX']
# ['small', 'ADJ']
# ['enough', 'ADV']
# ['to', 'PART']
# ['get', 'VERB']
# ['through', 'ADP']
# ['the', 'DET']
# ['door', 'NOUN']
# [',', 'PUNCT']
# ['she', 'PRON']
# ['ran', 'VERB']
# ['out', 'ADP']
# ['of', 'ADP']
# ['the', 'DET']
# ['house', 'NOUN']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['found', 'VERB']
# ['quite', 'DET']
# ['a', 'DET']
# ['crowd', 'NOUN']
# ['of', 'ADP']
# ['little', 'ADJ']
# ['animals', 'NOUN']
# ['and', 'CCONJ']
# ['birds', 'NOUN']
# ['waiting', 'VERB']
# ['outside', 'ADV']
# ['.', 'PUNCT']
# ['The', 'DET']
# ['poor', 'ADJ']
# ['little', 'ADJ']
# ['Lizard', 'NOUN']
# [',', 'PUNCT']
# ['Bill', 'PROPN']
# [',', 'PUNCT']
# ['was', 'AUX']
# ['in', 'ADP']
# ['the', 'DET']
# ['middle', 'NOUN']
# [',', 'PUNCT']
# ['being', 'AUX']
# ['held', 'VERB']
# ['up', 'ADP']
# ['by', 'ADP']
# ['two', 'NUM']
# ['guinea', 'NOUN']
# ['-', 'PUNCT']
# ['pigs', 'NOUN']
# [',', 'PUNCT']
# ['who', 'PRON']
# ['were', 'AUX']
# ['giving', 'VERB']
# ['it', 'PRON']
# ['something', 'PRON']
# ['out', 'ADP']
# ['of', 'ADP']
# ['a', 'DET']
# ['bottle', 'NOUN']
# ['.', 'PUNCT']
# ['They', 'PRON']
# ['all', 'PRON']
# ['made', 'VERB']
# ['a', 'DET']
# ['rush', 'NOUN']
# ['at', 'ADP']
# ['Alice', 'PROPN']
# ['the', 'DET']
# ['moment', 'NOUN']
# ['she', 'PRON']
# ['appeared', 'VERB']
# [',', 'PUNCT']
# ['but', 'CCONJ']
# ['she', 'PRON']
# ['ran', 'VERB']
# ['off', 'ADP']
# ['as', 'ADV']
# ['hard', 'ADV']
# ['as', 'SCONJ']
# ['she', 'PRON']
# ['could', 'AUX']
# [',', 'PUNCT']
# ['and', 'CCONJ']
# ['soon', 'ADV']
# ['found', 'VERB']
# ['herself', 'PRON']
# ['safe', 'ADJ']
# ['in', 'ADP']
# ['a', 'DET']
# ['thick', 'ADJ']
# ['wood', 'NOUN']
# ['.', 'PUNCT']
